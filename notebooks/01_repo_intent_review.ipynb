# %% [markdown]
# # Repository Intent Review
# Use this notebook to understand project intent before adding analysis or model code.

# %% [markdown]
# ## 1. Problem Story
# Write the project question in one sentence and describe who benefits from the result.

# %%
project_question = ""
primary_user = ""
decision_supported = ""

print('Question:', project_question)
print('User:', primary_user)
print('Decision:', decision_supported)

# %% [markdown]
# ## 2. Structure and Lifecycle
# Map each folder to a lifecycle stage: data acquisition, preparation, exploration, modeling, reporting, documentation.

# %%
lifecycle_map = {
    'data/raw': 'source snapshots',
    'data/processed': 'cleaned datasets',
    'notebooks': 'exploration and narrative analysis',
    'src': 'reusable logic',
    'reports/figures': 'final communication artifacts',
    'docs': 'intent, assumptions, contribution guidance'
}

for folder, purpose in lifecycle_map.items():
    print(f'{folder}: {purpose}')

# %% [markdown]
# ## 3. Assumptions and Gaps
# Capture assumptions, risks, and unresolved questions before writing new code.

# %%
assumptions = [
    'Air quality data is available for target city',
    'Weather features improve interpretability or forecast skill'
]
limitations = [
    'Health risk definition may vary by standard or location',
    'Data gaps can bias trends and model estimates'
]
open_questions = [
    'What target variable should be forecast?',
    'Which evaluation metric best reflects user value?'
]

print('Assumptions:')
for item in assumptions:
    print('-', item)

print('\nLimitations:')
for item in limitations:
    print('-', item)

print('\nOpen questions:')
for item in open_questions:
    print('-', item)

# %% [markdown]
# ## 4. Safe Contribution Plan
# Define one additive contribution that preserves existing intent and avoids breaking workflows.

# %%
first_change = {
    'type': 'additive notebook or script',
    'scope': 'new analysis only',
    'doc_update': 'update docs/checklist with assumptions and results'
}

first_change
